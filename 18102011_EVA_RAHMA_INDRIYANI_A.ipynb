# %% [markdown]
# <a href="https://colab.research.google.com/github/evarahma61/analisis-sentimen-Tolak_RUU_IKN/blob/main/18102011_EVA_RAHMA_INDRIYANI_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2> Nama : Eva Rahma Indriyani
# <h2> NIM  : 18102011

# %%
# !pip install twint #menginstall twint yaitu tools untuk crawling data tanpa keyAPI dan tanpa limitasi

# %%
# !git clone --depth=1 https://github.com/twintproject/twint.git
# %cd twint
# !pip3 install . -r requirements.txt
# Out:
# Cloning into 'twint'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 47 (delta 3), reused 14 (delta 0), pack-reused 0
# Unpacking objects: 100% (47/47), done.
# /content/twint/twint/twint
# Processing /content/twint/twint/twint
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#   Created wheel for twint: filename=twint-2.1.21-py3-none-any.whl size=38870 sha256=62e7867f8bfe51e1ab184e8839eb5e10970c73712f55d7b31d4b8c3adbdb5d01
# ...

# %%
import nest_asyncio
nest_asyncio.apply()# used once to enable concurrent actions within a Jupyter notebook.

# %%
import twint
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-5772b804c290> in <module>()
# ----> 1 import twint
#
# /content/twint/twint/twint/twint/__init__.py in <module>()
#      12 from .config import Config
#      13 from .__version__ import __version__
# ---> 14 from . import run
#      15
#      16 _levels = {
#
# /content/twint/twint/twint/twint/run.py in <module>()
#       2 from asyncio import get_event_loop, TimeoutError, ensure_future, new_event_loop, set_event_loop
#       3
# ----> 4 from . import datelock, feed, get, output, verbose, storage
#       5 from .token import TokenExpiryException
#       6 from . import token
#
# /content/twint/twint/twint/twint/get.py in <module>()
#      10 import random
#      11 from json import loads, dumps
# ---> 12 from aiohttp_socks import ProxyConnector, ProxyType
#      13 from urllib.parse import quote
#      14
#
# ...

# %% [markdown]
# <h3> Scrape tweets using twitter

# %%
# Configure
c = twint.Config() #
c.Search = '#TolakRUU_IKN' #hashtag yang akan dicari


c.Store_csv = True  # menyimpan data di file csv
c.Output = "18102011_EVA RAHMA INDRIYANI_A.csv"  # nama file untuk menyimpan csv

# Run
twint.run.Search(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ff8f7de96bcd> in <module>()
#       1 # Configure
# ----> 2 c = twint.Config() #
#       3 c.Search = '#TolakRUU_IKN' #hashtag yang akan dicari
#       4
#       5
#
# NameError: name 'twint' is not defined

# %%
import pandas as pd
df = pd.read_csv('18102011_EVA RAHMA INDRIYANI_A.csv')

# %%
df
# Out:
#                      id      conversation_id  ... trans_src trans_dest
# 0   1448294529149259776  1448294529149259776  ...       NaN        NaN
# 1   1447909667372367874  1447909667372367874  ...       NaN        NaN
# 2   1446840579787087873  1446840579787087873  ...       NaN        NaN
# 3   1446743096973086721  1446743096973086721  ...       NaN        NaN
# 4   1446685463767498760  1399725334182912008  ...       NaN        NaN
# 5   1446675746148143106  1446568331444555776  ...       NaN        NaN
# 6   1446618441574617091  1446257559237586945  ...       NaN        NaN
# 7   1446595056840818690  1446567724771995651  ...       NaN        NaN
# 8   1446587555973980161  1446587555973980161  ...       NaN        NaN
# 9   1446584139654729728  1446024716313976838  ...       NaN        NaN
# 10  1446571960704454656  1446567724771995651  ...       NaN        NaN
# 11  1446569113132810242  1446567724771995651  ...       NaN        NaN
#
# [12 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314 entries, 0 to 313
# Data columns (total 36 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               314 non-null    int64
#  1   conversation_id  314 non-null    int64
#  2   created_at       314 non-null    object
#  3   date             314 non-null    object
#  4   time             314 non-null    object
#  5   timezone         314 non-null    int64
#  6   user_id          314 non-null    int64
#  7   username         314 non-null    object
#  8   name             314 non-null    object
#  9   place            0 non-null      float64
#  10  tweet            314 non-null    object
#  11  language         314 non-null    object
#  12  mentions         314 non-null    object
#  13  urls             314 non-null    object
#  14  photos           314 non-null    object
#  15  replies_count    314 non-null    int64
#  16  retweets_count   314 non-null    int64
# ...

# %%
from IPython.display import HTML
import requests

def show_tweet(link):
    '''Display the contents of a tweet. '''
    url = 'https://publish.twitter.com/oembed?url=%s' % link
    response = requests.get(url)
    html = response.json()["html"]
    display(HTML(html))

# %%
sample_tweet_link = df.sample(1)['link'].values[0]
display(sample_tweet_link)
show_tweet(sample_tweet_link)
# Out:
# 'https://twitter.com/Tiara_hatiii/status/1446346185040486407'
# <blockquote class="twitter-tweet"><p lang="in" dir="ltr">Jelaslah kita harus <a href="https://twitter.com/hashtag/TolakRUU_IKN?src=hash&amp;ref_src=twsrc%5Etfw">#TolakRUU_IKN</a> <br>Rakyat lg sulit koq foya2 di tmpt yg gk penting<a href="https://twitter.com/hashtag/TolakRUU_IKN?src=hash&amp;ref_src=twsrc%5Etfw">#TolakRUU_IKN</a></p>&mdash; Tiara (@Tiara_hatiii) <a href="https://twitter.com/Tiara_hatiii/status/1446346185040486407?ref_src=twsrc%5Etfw">October 8, 2021</a></blockquote>
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
